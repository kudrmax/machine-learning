# %% [markdown]
# # Считывание данных

# %%
from sklearn.datasets import load_diabetes

data = load_diabetes()

X = data.data
y = data.target

# %%
X
# Out:
# array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990749, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06833155, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286131, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04688253,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452873, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00422151,  0.00306441]])

# %%
y
# Out:
# array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#         69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#         68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#         87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
#        259.,  53., 190., 142.,  75., 142., 155., 225.,  59., 104., 182.,
#        128.,  52.,  37., 170., 170.,  61., 144.,  52., 128.,  71., 163.,
#        150.,  97., 160., 178.,  48., 270., 202., 111.,  85.,  42., 170.,
#        200., 252., 113., 143.,  51.,  52., 210.,  65., 141.,  55., 134.,
#         42., 111.,  98., 164.,  48.,  96.,  90., 162., 150., 279.,  92.,
#         83., 128., 102., 302., 198.,  95.,  53., 134., 144., 232.,  81.,
#        104.,  59., 246., 297., 258., 229., 275., 281., 179., 200., 200.,
#        173., 180.,  84., 121., 161.,  99., 109., 115., 268., 274., 158.,
#        107.,  83., 103., 272.,  85., 280., 336., 281., 118., 317., 235.,
#         60., 174., 259., 178., 128.,  96., 126., 288.,  88., 292.,  71.,
#        197., 186.,  25.,  84.,  96., 195.,  53., 217., 172., 131., 214.,
#         59.,  70., 220., 268., 152.,  47.,  74., 295., 101., 151., 127.,
#        237., 225.,  81., 151., 107.,  64., 138., 185., 265., 101., 137.,
#        143., 141.,  79., 292., 178.,  91., 116.,  86., 122.,  72., 129.,
#        142.,  90., 158.,  39., 196., 222., 277.,  99., 196., 202., 155.,
#         77., 191.,  70.,  73.,  49.,  65., 263., 248., 296., 214., 185.,
#         78.,  93., 252., 150.,  77., 208.,  77., 108., 160.,  53., 220.,
#        154., 259.,  90., 246., 124.,  67.,  72., 257., 262., 275., 177.,
#         71.,  47., 187., 125.,  78.,  51., 258., 215., 303., 243.,  91.,
#        150., 310., 153., 346.,  63.,  89.,  50.,  39., 103., 308., 116.,
#        145.,  74.,  45., 115., 264.,  87., 202., 127., 182., 241.,  66.,
#         94., 283.,  64., 102., 200., 265.,  94., 230., 181., 156., 233.,
#         60., 219.,  80.,  68., 332., 248.,  84., 200.,  55.,  85.,  89.,
#         31., 129.,  83., 275.,  65., 198., 236., 253., 124.,  44., 172.,
#        114., 142., 109., 180., 144., 163., 147.,  97., 220., 190., 109.,
#        191., 122., 230., 242., 248., 249., 192., 131., 237.,  78., 135.,
#        244., 199., 270., 164.,  72.,  96., 306.,  91., 214.,  95., 216.,
#        263., 178., 113., 200., 139., 139.,  88., 148.,  88., 243.,  71.,
#         77., 109., 272.,  60.,  54., 221.,  90., 311., 281., 182., 321.,
#         58., 262., 206., 233., 242., 123., 167.,  63., 197.,  71., 168.,
#        140., 217., 121., 235., 245.,  40.,  52., 104., 132.,  88.,  69.,
#        219.,  72., 201., 110.,  51., 277.,  63., 118.,  69., 273., 258.,
#         43., 198., 242., 232., 175.,  93., 168., 275., 293., 281.,  72.,
#        140., 189., 181., 209., 136., 261., 113., 131., 174., 257.,  55.,
#         84.,  42., 146., 212., 233.,  91., 111., 152., 120.,  67., 310.,
#         94., 183.,  66., 173.,  72.,  49.,  64.,  48., 178., 104., 132.,
#        220.,  57.])

# %% [markdown]
# # Понижение размерности

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

lda = LinearDiscriminantAnalysis(n_components=1)
X_new = lda.fit_transform(X, y)

print(f"Исходные данные: {X.shape = }")
print(f"Данные после использования LDA: {X_new.shape = }")
# Out:
# Исходные данные: X.shape = (442, 10)
# Данные после использования LDA: X_new.shape = (442, 1)

# %%
X
# Out:
# array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990749, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06833155, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286131, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04688253,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452873, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00422151,  0.00306441]])

# %%
X_new
# Out:
# array([[ 1.66315006e+00],
#        [-2.31198262e+00],
#        [ 7.50925129e-01],
#        [ 4.25009179e-01],
#        [-7.60775288e-01],
#        [-7.10156564e-01],
#        [-1.73188851e+00],
#        [-1.29240797e+00],
#        [ 2.45281480e-01],
#        [ 2.12783063e+00],
#        [-8.40507780e-01],
#        [-1.83919208e+00],
#        [-9.89330926e-01],
#        [ 5.33336858e-01],
#        [-1.45889495e+00],
#        [ 2.32241071e-01],
#        [ 1.58416674e+00],
#        [ 7.21009335e-01],
#        [-1.43094029e-02],
#        [-5.64549073e-01],
#        [-5.99725930e-01],
#        [-1.50636825e+00],
#        [-8.95827753e-01],
#        [ 3.10011654e+00],
#        [ 3.97307559e-01],
#        [ 1.25371987e-01],
#        [-1.02649670e+00],
#        [ 7.82895070e-01],
#        [-2.80784465e-01],
#        [ 1.27090349e+00],
#        [ 3.12226223e-01],
#        [-1.87559825e+00],
#        [ 2.29554546e+00],
#        [-1.22378892e+00],
#        [-1.76544159e+00],
#        [-1.86713447e+00],
#        [ 1.75156457e+00],
#        [ 3.29554777e-01],
#        [ 2.14842899e+00],
#        [-1.80722029e-01],
#        [-2.28253180e-01],
#        [-1.83346359e+00],
#        [ 7.58990320e-02],
#        [-2.19882869e+00],
#        [ 1.66750124e+00],
#        [-6.44822963e-01],
#        [ 1.52758045e-01],
#        [-5.72795042e-01],
#        [-2.11753033e+00],
#        [ 9.66993090e-01],
#        [ 2.44377706e-01],
#        [ 5.29118323e-01],
#        [-6.15340220e-01],
#        [-2.14308742e-01],
#        [-4.19598776e-01],
#        [-2.36220768e+00],
#        [ 1.72576650e+00],
#        [-1.60509102e+00],
#        [-1.63326115e+00],
#        [-5.04276570e-01],
#        [-7.01330933e-01],
#        [ 7.21918146e-01],
#        [-2.40447177e+00],
#        [-1.25271394e+00],
#        [-8.24802054e-01],
#        [ 8.33770533e-01],
#        [-3.30474703e-01],
#        [-7.21513527e-01],
#        [-9.86854588e-01],
#        [-7.01233416e-01],
#        [-2.36721499e+00],
#        [ 2.11207149e+00],
#        [ 2.13080040e-03],
#        [-9.66559324e-01],
#        [-5.89905691e-02],
#        [-5.07342781e-01],
#        [ 1.50221209e+00],
#        [-1.80324091e+00],
#        [ 8.79935380e-01],
#        [-1.68092795e+00],
#        [ 2.76920700e-01],
#        [-9.53054329e-01],
#        [-2.54651573e+00],
#        [ 3.49925526e-01],
#        [-2.34240602e+00],
#        [ 4.73898845e-01],
#        [-2.64979612e+00],
#        [-9.77450949e-03],
#        [-1.84602227e+00],
#        [-1.32611785e+00],
#        [-1.91432862e+00],
#        [ 7.16275417e-01],
#        [ 9.45623522e-01],
#        [-2.26303587e+00],
#        [ 1.53634887e-01],
#        [ 1.72804920e+00],
#        [-2.49454348e-02],
#        [-1.82340199e+00],
#        [-1.82046961e+00],
#        [-7.03572699e-01],
#        [ 8.16124231e-01],
#        [ 1.42356285e+00],
#        [-3.75096161e-01],
#        [ 5.11046142e-01],
#        [-4.99812163e-01],
#        [-8.06688205e-02],
#        [-3.80953541e-01],
#        [ 2.60671199e+00],
#        [-1.41621158e+00],
#        [-1.12826968e+00],
#        [-7.85222741e-01],
#        [ 1.54381619e+00],
#        [-2.79492275e+00],
#        [-6.56048852e-01],
#        [-8.37331024e-01],
#        [-2.49064414e+00],
#        [ 1.25361305e+00],
#        [-1.51464479e+00],
#        [-8.10189965e-01],
#        [ 1.68457683e+00],
#        [-3.09235486e+00]])

# %% [markdown]
# # Разделение на обучающую и тестовую выборки

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_new, y, train_size=0.7)

# %% [markdown]
# # Реализация класса MyLinearRegression

# %%
import numpy as np


class MyLinearRegression:
    def __init__(self):
        self.w = None

    def fit_analytic(self, X, y):
        """
        Метод для вычисления весов аналитически.

        Parameters
        ----------
        X: матрица признаков.
        y: вектор целевых переменных.
        """
        X = self._change_X_shape(X)

        self.w = np.linalg.inv(X.T @ X) @ X.T @ y

        return self

    def fit(self, X, y, type='MSE', lr=0.01, max_iter=1000):
        """
        Метод для вычисления весов через градиентный спуск.

        Parameters
        ----------
        type: тип ошибки, которую будем минимизировать ('MSE', 'MAE')
        X_train: матрица признаков.
        y: вектор целевых переменных.
        lr: коэффициент для линейной регрессии.
        max_iter: максимальное количество итерация градиентного спуска.
        """
        X_train = self._change_X_shape(X)

        if self.w is None:
            self.w = np.random.randn(X_train.shape[1])

        for iter in range(max_iter):
            y_pred = self.predict(X)
            grad = self._calc_gradient(X_train, y, y_pred, type)
            self.w -= lr * grad

        return self

    def predict(self, X):
        """
        Метод для предсказания целевой переменной.

        Parameters
        ----------
        X: матрица признаков

        Returns
        -------
        Вектор предсказанных значений целевой переменной.
        """
        X = self._change_X_shape(X)

        y_pred = X @ self.w

        return y_pred

    def _calc_gradient(self, X, y, y_pred, type):
        """
        Метод для вычисления градиента.

        Parameters
        ----------
        X_train: матрица признаков.
        y: вектор целевых переменных.
        y_pred: вектор предсказаных значений целевой переменной.
        type: тип ошибки, которую будем минимизировать ('MSE', 'MAE').

        Returns
        -------
        Градиент
        """
        # grad = np.zeros(2, dtype=float)
        delta_y = (y - y_pred).reshape(-1, 1)
        if type == 'MSE':
            grad = (-2 * X * delta_y).mean(axis=0)
        elif type == 'MAE':
            grad = (- X * delta_y / np.abs(delta_y)).mean(axis=0)
        return grad

    def _change_X_shape(self, X):
        """
        Метод добавляет фиктивный единичный признак к матрице признаков X. Это удобно для вычисления градиента.

        Parameters
        ----------
        X: матрица признаков

        Returns
        -------
        Новая матрица признаков с фиктивным признаком
        """
        return np.hstack((X, np.ones((X.shape[0], 1))))

# %% [markdown]
# # Использование собственного класса LinearRegression

# %%
# аналитическое решение

clf = MyLinearRegression()

clf.fit(X_train, y_train, type='MSE')
y_pred_analytic = clf.predict(X_test)

# %%
# MSE

clf = MyLinearRegression()

clf.fit(X_train, y_train, type='MSE')
y_pred_MSE = clf.predict(X_test)

# %%
# MAE

clf = MyLinearRegression()

clf.fit(X_train, y_train, type='MAE', max_iter=100000)
y_pred_MAE = clf.predict(X_test)

# %%
# sklearn

from sklearn.linear_model import LinearRegression

clf = LinearRegression()

clf.fit(X_train, y_train)
y_pred_sklearn = clf.predict(X_test)

# %%
import matplotlib.pyplot as plt


def get_line(weight, x):
    return weight[0] * x + weight[1]


plt.figure(figsize=(10, 7))

plt.plot(X_test, y_pred_analytic, label='MyLinearRegression analytic', c='k')
plt.plot(X_test, y_pred_MSE, label='MyLinearRegression with MSE', c='orange')
plt.plot(X_test, y_pred_sklearn, label='LinearRegression sklearn', c='c', linestyle=':')
plt.plot(X_test, y_pred_MAE, label='MyLinearRegression with MAE', c='g')

plt.scatter(X_train, y_train, label='Train', c='r', s=10)
plt.scatter(X_test, y_test, label='Test', c='b', s=10)

# plt.scatter(X_test, y_pred_MSE, label='Predicted MSE', c='y')
# plt.scatter(X_test, y_pred_MAE, label='Predicted MAE', c='y')

plt.grid(alpha=0.2)
plt.legend()
plt.show()

# %% [markdown]
# Видно, что MyLinearRegression с MSE, с MAE и аналитическое решение совпали с решением через LinearRegression из sklearn. Замечу, что для MyLinearRegression через MAE требуется СИЛЬНО больше шагов (100000 vs 1000)

# %% [markdown]
# # Сравнение метрик

# %%
from sklearn.metrics import mean_squared_error, mean_squared_log_error, mean_absolute_error, r2_score


def root_mean_squared_error(y_test, y_pred):
    return np.sqrt(mean_squared_error(y_test, y_pred))


metrics = [
    mean_squared_error,
    root_mean_squared_error,
    mean_squared_log_error,
    mean_absolute_error,
    r2_score
]

d = {}

for metric in metrics:
    metric_name = metric.__name__
    if metric_name not in d:
        d[metric_name] = {}
    d[metric_name]['y_pred_for_my_MSE'] = metric(y_test, y_pred_MSE)
    d[metric_name]['y_pred_for_my_MAE'] = metric(y_test, y_pred_MAE)
    d[metric_name]['y_pred_from_sklearn'] = metric(y_test, y_pred_sklearn)

for metric in metrics:
    metric_name = metric.__name__
    print(f'Метрика: {metric_name}')
    for m in d[metric_name]:
        print(f'{m}: {d[metric_name][m]}')
    print()
# Out:
# Метрика: mean_squared_error
# y_pred_for_my_MSE: 3548.0629981722486
# y_pred_for_my_MAE: 3542.5573893158576
# y_pred_from_sklearn: 3548.0630015167494
#
# Метрика: root_mean_squared_error
# y_pred_for_my_MSE: 59.56561926289568
# y_pred_for_my_MAE: 59.51938666784007
# y_pred_from_sklearn: 59.565619290969764
#
# Метрика: mean_squared_log_error
# y_pred_for_my_MSE: 0.2142471013202922
# y_pred_for_my_MAE: 0.2158291480717877
# y_pred_from_sklearn: 0.21424710116732978
#
# Метрика: mean_absolute_error
# y_pred_for_my_MSE: 47.44691997483523
# y_pred_for_my_MAE: 47.44096108010876
# y_pred_from_sklearn: 47.44691998954703
#
# Метрика: r2_score
# y_pred_for_my_MSE: 0.2921237760429485
# y_pred_for_my_MAE: 0.2932222034411808
# y_pred_from_sklearn: 0.292123775375685

# %% [markdown]
# Видно, что значения практически не отличаются. У MyLinearRegression с MAE чуть значения иногда чуть отличаются от MyLinearRegression с MSE и LinearRegression из sklearn
